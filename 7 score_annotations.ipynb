# %%
#select 100 random files from data/annotations folder
import os
import random
import shutil
import glob
import argparse
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tkinter as tk
from tkinter import simpledialog, messagebox

# ...existing code...
#set seed
random.seed(42)

all_files = glob.glob(os.path.join("data/annotations", '*'))

#check that selected files have chunk number in annotations
confirmed_files = []
annotation_output = {}
chunk_output = {}

while len(confirmed_files) < 100:
    selected_file = random.choice(all_files)
    if selected_file in confirmed_files:
        continue
    with open(selected_file, 'r') as f:
        data = json.load(f)

    person, annotations = next(iter(data.items()))
    annotation = random.choice(annotations)
    if 'chunk' in annotation:
        confirmed_files.append(selected_file)

        key = person + os.path.basename(selected_file)
        chunk_id = str(annotation["chunk"])
        chunk_key = chunk_id + os.path.basename(selected_file)

        annotation_output[key] = [{
            "trait": annotation["trait"],
            "action": annotation["action"],
            "assessment": annotation["assessment"],
            "rating": annotation["rating"],
            "chunk": chunk_key
        }]

        chunk_file = os.path.join("data/chunks", os.path.basename(selected_file))
        with open(chunk_file, 'r') as f:
            chunks = json.load(f)
            chunk_text = chunks.get(chunk_id, "")
            chunk_output[chunk_key] = chunk_text

print(len(confirmed_files))

# write to data/random_annotations/annotations.json and data/random_annotations/chunks.json
os.makedirs("data/random_annotations", exist_ok=True)
with open("data/random_annotations/annotations.json", 'w') as f:
    json.dump(annotation_output, f, indent=4)
with open("data/random_annotations/chunks.json", 'w') as f:
    json.dump(chunk_output, f, indent=4)
# ...existing code...
# Out:
# 100

# %%
from llm_annotate import score_annotations
score_annotations(annotation_file="data/random_annotations/annotations.json", chunkfile="data/random_annotations/chunks.json", outputfile="data/random_annotations/scored_annotations.json", labels=["-3", "-2", "-1", "0", "1", "2", "3"])
# Out:
# Scoring 100 out of 100 total annotations.
